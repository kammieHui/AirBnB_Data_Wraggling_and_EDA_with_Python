# %% [markdown]
# <h2>Import Libraries</h2>

# %%
import numpy as np # Data manipulation
import pandas as pd # Numerical operations
import matplotlib.pyplot as plt # Plotting and visualization
import seaborn as sns # Statistical data visualization
import warnings  # Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h2>Import Data</h2>

# %%
# Read CSV
df = pd.read_csv('/Users/kammiehui/Jupyter Notebook/DataSet/Airbnb_Open_Data.csv')
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# <h3>Converting columns into snake case and removing irrelevant features </h3>

# %%
df.rename(lambda x: x.lower().strip().replace(' ', '_'), axis='columns', inplace=True)

# %%
print(f"DataFrame Shape (rows, columns) = {df.shape}")
print(df.columns)
# Out:
# DataFrame Shape (rows, columns) = (102599, 26)
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules', 'license'],
#       dtype='object')

# %% [markdown]
# <H3>Overview Listing Reference</H3>

# %%
def data_overview(df, sort_by='Null %', ascending=False):
    summary = []

    for col in df.columns:
        col_dtype = df[col].dtype
        unique_vals = df[col].nunique()
        null_vals = df[col].isnull().sum()
        total_vals = len(df)
        null_pct = round((null_vals / total_vals) * 100, 2)

        summary.append([
            col,
            col_dtype,
            unique_vals,
            null_vals,
            null_pct
        ])
    
    df_summary = pd.DataFrame(
        summary,
        columns=['Column', 'Data Type', 'Unique Values', 'Null Values', 'Null %']
    )

    df_summary = df_summary.sort_values(by=sort_by, ascending=ascending)

    return df_summary
data_overview(df)
# Out:
#                             Column Data Type  Unique Values  Null Values  \
# 25                         license    object              1       102597
# 24                     house_rules    object           1976        52131
# 19                     last_review    object           2477        15893
# 20               reviews_per_month   float64           1016        15879
# 9                          country    object              1          532
# 23                availability_365   float64            438          448
# 4                        host_name    object          13190          406
# 17                  minimum_nights   float64            153          409
# 21              review_rate_number   float64              5          326
# 22  calculated_host_listings_count   float64             78          319
# 3           host_identity_verified    object              2          289
# 16                     service_fee    object            231          273
# 1                             name    object          61281          250
# 15                           price    object           1151          247
# 14               construction_year   float64             20          214
# 18               number_of_reviews   float64            476          183
# 10                    country_code    object              1          131
# 11                instant_bookable    object              2          105
# 12             cancellation_policy    object              3           76
# 5              neighbourhood_group    object              7           29
# 6                    neighbourhood    object            224           16
# 8                             long   float64          17774            8
# 7                              lat   float64          21991            8
# 0                               id     int64         102058            0
# 2                          host_id     int64         102057            0
# 13                       room_type    object              4            0
#
#     Null %
# 25  100.00
# 24   50.81
# 19   15.49
# 20   15.48
# 9     0.52
# 23    0.44
# 4     0.40
# 17    0.40
# 21    0.32
# 22    0.31
# 3     0.28
# 16    0.27
# 1     0.24
# 15    0.24
# 14    0.21
# 18    0.18
# 10    0.13
# 11    0.10
# 12    0.07
# 5     0.03
# 6     0.02
# 8     0.01
# 7     0.01
# 0     0.00
# 2     0.00
# 13    0.00

# %% [markdown]
# <H3>Examine and Remove Duplicate Rows</H3>

# %%
duplicated_rows = df.duplicated().sum()
print(f"\nTotal duplicated rows: {duplicated_rows}")
# Out:
# Total duplicated rows: 541

# %%
duplicate_rows = df[df.duplicated()].sort_values(by='id', ascending=False)
duplicate_rows
# Out:
#               id                                               name  \
# 102241  35607902                   Modern NEW Room|PRIVATE BATHROOM
# 102240  35607349         Modern & Bright Queen Bedroom Midtown East
# 102239  35606797        Bright and Beautiful Top Floor Two Bedrooms
# 102238  35606245  Che' Randall Tre   SoBro 10 Minutes to Manhattan!
# 102237  35605693  Huge Solo Room near Midtown, 61st station & st...
# ...          ...                                                ...
# 102478   6028371        *JAMES* Amazing Spacious 2 Bedroom- Bright!
# 102477   6027818    *ENCHANTMENT* Upper East Side 2 bedroom- Sunny!
# 102476   6027266  ACADIA Spacious 2 Bedroom Apt - Close to Hospi...
# 102475   6026714  Close to East Side Hospitals- Modern 2 Bedroom...
# 102474   6026161     Upper East Side 2 bedroom- close to Hospitals-
#
#             host_id host_identity_verified       host_name  \
# 102241   7431680152               verified  Dariia & Jacob
# 102240  57770451783            unconfirmed           David
# 102239  65331079885            unconfirmed         Frankie
# 102238  27445218777            unconfirmed            Rawn
# 102237  75670762826            unconfirmed             Kaz
# ...             ...                    ...             ...
# 102478  37678424985               verified         Juliana
# 102477  73401481508            unconfirmed         Juliana
# 102476  95854111798               verified         Juliana
# 102475  31072202372               verified         Juliana
# 102474  65193709566               verified         Juliana
#
#        neighbourhood_group       neighbourhood       lat      long  \
# 102241            Brooklyn  Bedford-Stuyvesant  40.68990 -73.94074
# 102240           Manhattan     Upper East Side  40.76132 -73.96064
# 102239            Brooklyn     Carroll Gardens  40.68383 -73.99281
# 102238               Bronx            Longwood  40.81992 -73.90790
# 102237              Queens            Woodside  40.74482 -73.90660
# ...                    ...                 ...       ...       ...
# 102478           Manhattan     Upper East Side  40.76035 -73.96133
# 102477           Manhattan     Upper East Side  40.76244 -73.96031
# 102476           Manhattan     Upper East Side  40.76021 -73.96157
# 102475           Manhattan     Upper East Side  40.76249 -73.96217
# 102474           Manhattan     Upper East Side  40.76222 -73.96030
#
#               country  ... service_fee minimum_nights number_of_reviews  \
# 102241  United States  ...        $57            30.0               1.0
# 102240  United States  ...        $28            30.0               1.0
# 102239  United States  ...       $205            30.0              18.0
# 102238  United States  ...       $239            30.0               9.0
# 102237  United States  ...       $234            30.0               3.0
# ...               ...  ...         ...            ...               ...
# 102478  United States  ...       $161            30.0               8.0
# 102477  United States  ...       $108            30.0               9.0
# 102476  United States  ...       $117            30.0              10.0
# 102475  United States  ...        $57            30.0               6.0
# 102474  United States  ...        $21            30.0               2.0
#
#        last_review  reviews_per_month review_rate_number  \
# 102241   11/4/2021               0.25                2.0
# 102240   11/4/2021               0.25                3.0
# 102239   11/4/2021               0.63                2.0
# 102238   11/4/2021               0.34                5.0
# 102237   11/4/2021               0.18                4.0
# ...            ...                ...                ...
# 102478   6/11/2019               0.27                4.0
# 102477   9/30/2018               0.20                5.0
# 102476  11/18/2018               0.22                5.0
# 102475   1/31/2019               0.14                3.0
# 102474    6/8/2019               0.21                3.0
#
#        calculated_host_listings_count  availability_365  \
# 102241                           10.0             365.0
# 102240                            4.0             307.0
# 102239                            1.0               3.0
# 102238                            3.0             338.0
# 102237                          161.0             365.0
# ...                               ...               ...
# 102478                           34.0             411.0
# 102477                           34.0             411.0
# 102476                           34.0             211.0
# 102475                           34.0              67.0
# 102474                           34.0             157.0
#
#                                               house_rules license
# 102241                                                NaN     NaN
# 102240                                                NaN     NaN
# 102239                                                NaN     NaN
# 102238                                                NaN     NaN
# 102237                                                NaN     NaN
# ...                                                   ...     ...
# 102478  Be courteous and respectful to people in the h...     NaN
# 102477  Please treat it as it were your own home and b...     NaN
# 102476                                 No Smoking No Pets     NaN
# 102475  The quieter the better, but otherwise make you...     NaN
# 102474                                                NaN     NaN
#
# [541 rows x 26 columns]

# %%
#Keep the first row and drop the 2nd row duplicate
df.drop_duplicates(keep='first', inplace=True)

# %%
print(f"DataFrame Shape (rows, columns) = {df.shape}")
# duplicates has been removed
# Out:
# DataFrame Shape (rows, columns) = (102058, 26)

# %% [markdown]
# <h3>Drop columns which is not helpful for further analysis</h3>

# %%
df = df.drop(['name', 'host_id', 'host_name', 'country', 'country_code', 'license'], axis =1)

# %% [markdown]
# ### Replace typo values
#
# <h4> There are some typo in <code>neighbourhood_group</code>. We will standardise them here.</h4>

# %%
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        43557
# Brooklyn         41630
# Queens           13197
# Bronx             2694
# Staten Island      949
# brookln              1
# manhatan             1
# Name: count, dtype: int64

# %%
# Replace typo values
df['neighbourhood_group'].replace(['manhatan','brookln'],['Manhattan','Brooklyn'],inplace=True)

# %%
# Verify Replacement
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        43558
# Brooklyn         41631
# Queens           13197
# Bronx             2694
# Staten Island      949
# Name: count, dtype: int64

# %% [markdown]
# <h3>Remove $ and ' , ' symbols in  <code>price</code>  and <code>service_fee</code> columns. </h3>

# %%
print(df['price'].value_counts())
# Out:
# price
# $206       135
# $1,056     131
# $481       129
# $833       127
# $573       126
#           ...
# $923        57
# $369        57
# $786        54
# $89         53
# $187        52
# Name: count, Length: 1151, dtype: int64

# %%
df[['price', 'service_fee']].dtypes
# Out:
# price          object
# service_fee    object
# dtype: object

# %%
# to remove $ and , in  price and service fee columns and change to float type
# will handle NaN value later
df['price'] = pd.to_numeric(df['price'].str.replace('$', '').str.replace(',', ''), errors='coerce')
df['service_fee'] = pd.to_numeric(df['service_fee'].str.replace('$', '').str.replace(',', ''), errors='coerce')

# %%
# confirm changes is made
print(df['price'].dtype)  
print(df['service_fee'].dtype)
# Out:
# float64
# float64

# %% [markdown]
# <h3>Continue Handling <code>price</code> and <code>service_fee</code> Columns,  replace NaN by Mean Value. </h3>

# %%
#Now handle the NaN value of price and service_fee
avg_price = round(df['price'].astype('float').mean(axis=0),0)
print(f"Mean Price is : {avg_price}")

avg_sev_fee = round(df['service_fee'].astype('float').mean(axis=0),0)
print(f"Mean Service Charge is : {avg_sev_fee}")
# Out:
# Mean Price is : 625.0
# Mean Service Charge is : 125.0

# %% [markdown]
# <h4> Now we have the mean value to replace null value in <code>price</code> and <code>service_fee</code> Columns. </h4>

# %%
df['price'].replace(np.nan, avg_price, inplace = True)
df['service_fee'].replace(np.nan,avg_sev_fee, inplace = True)

# %% [markdown]
# <h3>Handling Incorrect / Values </h3>
# <h4> Negative values found on <code>minimum_nights</code> and <code>availability_365</code>, here will replace negative values to NaN first and then replace NaN with top Count</h4>

# %%
print(df['minimum_nights'].value_counts().sort_index(ascending=True))
print(df['availability_365'].value_counts().sort_index(ascending=True))
# Out:
# minimum_nights
# -1223.0    1
# -365.0     1
# -200.0     1
# -125.0     1
# -12.0      1
#           ..
#  1000.0    2
#  1250.0    1
#  2645.0    1
#  3455.0    1
#  5645.0    1
# Name: count, Length: 153, dtype: int64
# availability_365
# -10.0      37
# -9.0       47
# -8.0       50
# -7.0       36
# -6.0       31
#            ..
#  423.0     48
#  424.0     38
#  425.0     49
#  426.0     46
#  3677.0     1
# Name: count, Length: 438, dtype: int64

# %%
# Identify how many rows where values are negative
negative_minimum_nights = df[df['minimum_nights'] < 0]
negative_availability = df[df['availability_365'] < 0]

# Display counts of negative values
print(f"Negative 'minimum_nights': {negative_minimum_nights.shape[0]}")
print(f"Negative 'availability_365': {negative_availability.shape[0]}")
# Out:
# Negative 'minimum_nights': 13
# Negative 'availability_365': 431

# %%
# we will first replace with NaN values first and then clean up NaN value one time 
df['minimum_nights'] = df['minimum_nights'].apply(lambda x: x if x >= 0 else np.nan)
df['availability_365'] = df['availability_365'].apply(lambda x: x if x >= 0 else np.nan)

# %% [markdown]
# <h3>Replace NaN with Top Count Value</h3>

# %%
# REPLACE MOST VALUE COUNT for below columns

print(df['host_identity_verified'].value_counts())
print(df['cancellation_policy'].value_counts())
print(df['review_rate_number'].value_counts())
print(df['minimum_nights'].value_counts())
print(df['availability_365'].value_counts())
print(df['calculated_host_listings_count'].value_counts())
print(df['number_of_reviews'].value_counts())
# Out:
# host_identity_verified
# unconfirmed    50944
# verified       50825
# Name: count, dtype: int64
# cancellation_policy
# moderate    34162
# strict      33929
# flexible    33891
# Name: count, dtype: int64
# review_rate_number
# 5.0    23251
# 4.0    23200
# 3.0    23130
# 2.0    22972
# 1.0     9186
# Name: count, dtype: int64
# minimum_nights
# 1.0      25290
# 2.0      23495
# 3.0      16038
# 30.0     11554
# 4.0       6606
#          ...
# 74.0         1
# 198.0        1
# 81.0         1
# 43.0         1
# 825.0        1
# Name: count, Length: 143, dtype: int64
# availability_365
# 0.0       23448
# 365.0      2484
# 364.0      1162
# 89.0        746
# 1.0         731
#           ...
# 375.0        32
# 412.0        32
# 391.0        30
# 401.0        30
# 3677.0        1
# Name: count, Length: 428, dtype: int64
# calculated_host_listings_count
# 1.0     63121
# 2.0     14380
# 3.0      6536
# 4.0      3529
# 5.0      1977
#         ...
# 86.0       21
# 22.0       20
# 55.0       15
# 46.0        9
# 80.0        7
# Name: count, Length: 78, dtype: int64
# number_of_reviews
# 0.0      15673
# 1.0      10348
# 2.0       7129
# 3.0       5341
# 4.0       4125
#          ...
# 567.0        1
# 592.0        1
# 797.0        1
# 966.0        1
# 300.0        1
# Name: count, Length: 476, dtype: int64

# %%
# Replace Nan Value with top count
df['host_identity_verified'].replace(np.nan, 'unconfirmed', inplace=True)
df['cancellation_policy'].replace(np.nan, 'moderate', inplace=True)
df['review_rate_number'].replace(np.nan, 5, inplace=True)
df['minimum_nights'].replace(np.nan, 1, inplace=True)
df['availability_365'].replace(np.nan, 0, inplace=True)
df['calculated_host_listings_count'].replace(np.nan, 1, inplace=True)
df['number_of_reviews'].replace(np.nan, 0, inplace=True)

# %% [markdown]
# <h3>Handle unrealistic date values</h3>
# <h4>Future Dates Value found in column <code>last_review</code>. Here will replace future dates and NaT to mean_date.</h4>

# %%
df['last_review'] = pd.to_datetime(df['last_review']) # Resetting the index for better readability
print(df['last_review'].sort_values(ascending=False))
# Out:
# 255      2058-06-16
# 483      2040-06-16
# 318      2026-03-28
# 191      2025-06-26
# 127      2024-08-15
#             ...
# 102035          NaT
# 102037          NaT
# 102045          NaT
# 102051          NaT
# 102056          NaT
# Name: last_review, Length: 102058, dtype: datetime64[ns]

# %%
# Define a realistic upper limit (today's date, for example)
from datetime import datetime
today = pd.to_datetime(datetime.today().date())

# Filter valid dates (excluding future errors)
valid_dates = df[df['last_review'] <= today]['last_review'] 

# Calculate mean date
mean_date = valid_dates.mean()

print(f"Calculated Mean Date: {mean_date}")
# Out:
# Calculated Mean Date: 2019-06-10 18:47:53.419776768

# %%
# Replace NaT values with mean date
df['last_review'].fillna(mean_date, inplace=True)

# Replace unrealistically high dates with mean date
df.loc[df['last_review'] > today, 'last_review'] = mean_date

print(df['last_review'].sort_values(ascending=False).head())
# Out:
# 127     2024-08-15
# 1       2022-05-21
# 1099    2022-05-05
# 69275   2022-05-05
# 784     2022-05-04
# Name: last_review, dtype: datetime64[ns]

# %% [markdown]
# <h3>Replace <code>reviews_per_month</code> null values by Mean</h3>

# %%
df['reviews_per_month'].value_counts()
# Out:
# reviews_per_month
# 1.00     17272
# 0.03      1665
# 0.05      1489
# 0.09      1264
# 0.04      1260
#          ...
# 9.10         1
# 10.36        1
# 8.50         1
# 15.32        1
# 33.08        1
# Name: count, Length: 1016, dtype: int64

# %%
avg_mth_views = round(df['reviews_per_month'].astype('float').mean(axis=0),0)
print(f"Average monthly reviews:{avg_mth_views}")
# Out:
# Average monthly reviews:1.0

# %%
df['reviews_per_month'].replace(np.nan, 1, inplace=True)

# %% [markdown]
# <h3> Convert <code>instant_bookable</code> to `Boolean`type and replace NaN with Top Value Count  </h3>

# %%
df['instant_bookable'] = df['instant_bookable'].astype(str).str.strip().str.lower()
df['instant_bookable'] = df['instant_bookable'].fillna('false')  # Replace NaN first
df['instant_bookable'] = df['instant_bookable'].eq('true')  # Convert to Boolean

# %%
df['instant_bookable'].value_counts()
# Out:
# instant_bookable
# False    51291
# True     50767
# Name: count, dtype: int64

# %% [markdown]
# <h3>Use Forward Filling and Backward Filling</h3>
# <

# %%
df['construction_year'].fillna(method='ffill', inplace=True)  # Fill forward first
df['construction_year'].fillna(method='bfill', inplace=True)  # Then fill backward

# %% [markdown]
# <H3> Handling NaN house_rules</H3>
# <h4> Although there are 50% null value, but there are still more than 50K rows with vlaues which may useful for further analysis. Therefore, we will replace the NaN with <code>No specific rules provided<code> </h4>

# %%
print(f"house_rules null values: {df['house_rules'].isnull().sum()}")
# Out:
# house_rules null values: 51842

# %%
df['house_rules'].fillna('No specific rules provided', inplace=True)

# %% [markdown]
# <h3>Now review again the null values in the list</h3>

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# neighbourhood_group               29
# neighbourhood                     16
# lat                                8
# long                               8
# id                                 0
# minimum_nights                     0
# availability_365                   0
# calculated_host_listings_count     0
# review_rate_number                 0
# reviews_per_month                  0
# last_review                        0
# number_of_reviews                  0
# price                              0
# service_fee                        0
# host_identity_verified             0
# construction_year                  0
# room_type                          0
# cancellation_policy                0
# instant_bookable                   0
# house_rules                        0
# dtype: int64

# %% [markdown]
# <h3>Change categorial data type to Category</h3>

# %%
df = df.astype({'cancellation_policy':'category','room_type':'category','host_identity_verified':'category', 'review_rate_number':'category'})

# %% [markdown]
# <h3>Remove Rows with Nan Values  </h3>
# <h4>Below columns contribute less than 0.5% null values of its column, we will choose to drop the row with null values</h4>
# - neighbourhood_group...... 29<br>
# - neighbourhood............ 16<br>
# - lat...................... 8<br>
# - long..................... 8<br>

# %%
# REVIEW selected rows with NaN Values
nan_rows = df[df[['neighbourhood_group', 'neighbourhood', 'lat', 'long']].isnull().any(axis=1)]
nan_rows
# Out:
#              id host_identity_verified neighbourhood_group  \
# 74      1042206            unconfirmed                 NaN
# 75      1042759            unconfirmed                 NaN
# 76      1043311               verified                 NaN
# 77      1043863               verified                 NaN
# 78      1044415            unconfirmed                 NaN
# 90      1051043            unconfirmed                 NaN
# 91      1051595            unconfirmed                 NaN
# 92      1052148            unconfirmed                 NaN
# 148     1083076               verified                 NaN
# 161     1090256            unconfirmed                 NaN
# 168     1094122            unconfirmed                 NaN
# 196     1109587               verified                 NaN
# 206     1115110            unconfirmed                 NaN
# 241     1134440               verified                 NaN
# 249     1138859            unconfirmed                 NaN
# 262     1146039               verified                 NaN
# 287     1159846            unconfirmed                 NaN
# 295     1164265            unconfirmed                 NaN
# 307     1170892               verified                 NaN
# 319     1177520               verified                 NaN
# 361     1200716               verified                 NaN
# 384     1213419            unconfirmed                 NaN
# 415     1230541            unconfirmed                 NaN
# 448     1248766            unconfirmed                 NaN
# 465     1258156            unconfirmed                 NaN
# 488     1270858               verified                 NaN
# 492     1273068               verified                 NaN
# 517     1286875            unconfirmed            Brooklyn
# 547     1303444               verified           Manhattan
# 553     1306758            unconfirmed           Manhattan
# 575     1318909            unconfirmed           Manhattan
# 589     1326641               verified            Brooklyn
# 613     1339896               verified           Manhattan
# 624     1345971            unconfirmed           Manhattan
# 633     1350942               verified           Manhattan
# 643     1356465               verified            Brooklyn
# 670     1371377               verified            Brooklyn
# 678     1375795               verified            Brooklyn
# 681     1377452            unconfirmed            Brooklyn
# 726     1402306               verified           Manhattan
# 731     1405067            unconfirmed           Manhattan
# 760     1421084               verified            Brooklyn
# 770     1426607            unconfirmed            Brooklyn
# 779     1431578            unconfirmed            Brooklyn
# 785     1434892            unconfirmed            Brooklyn
# 799     1442624               verified           Manhattan
# 814     1450908               verified           Manhattan
# 843     1466925               verified              Queens
# 885     1490122            unconfirmed            Brooklyn
# 926     1512766            unconfirmed           Manhattan
# 986     1545904            unconfirmed           Manhattan
# 40383  23304867            unconfirmed                 NaN
# 40396  23312047            unconfirmed                 NaN
#
#             neighbourhood       lat      long  instant_bookable  \
# 74     Washington Heights  40.83139 -73.94095              True
# 75           Clinton Hill  40.68346 -73.96374              True
# 76           East Village  40.72828 -73.98801             False
# 77        Upper East Side  40.76865 -73.95058             False
# 78               Woodside  40.75038 -73.90334              True
# 90           Williamsburg  40.71156 -73.96218             False
# 91               Bushwick  40.70032 -73.93830             False
# 92       Prospect Heights  40.68233 -73.97261             False
# 148          East Village  40.72354 -73.98295             False
# 161          Williamsburg  40.71088 -73.95055             False
# 168          Clinton Hill  40.68843 -73.96408              True
# 196               Chelsea  40.74859 -73.99671              True
# 206      Prospect Heights  40.67870 -73.97262             False
# 241           East Harlem  40.80942 -73.93936             False
# 249              Bushwick  40.68800 -73.91710              True
# 262           Eastchester  40.88057 -73.83572              True
# 287          Williamsburg  40.71031 -73.95830             False
# 295                Harlem  40.82976 -73.94867             False
# 307             Chinatown  40.71659 -73.98945              True
# 319          Williamsburg  40.71398 -73.95763             False
# 361        Queens Village  40.72413 -73.76133              True
# 384                Harlem  40.82399 -73.95328              True
# 415          Williamsburg  40.71363 -73.96019              True
# 448    Bedford-Stuyvesant  40.68669 -73.91989             False
# 465          East Village  40.72636 -73.98917              True
# 488           East Harlem  40.79320 -73.94007             False
# 492                Harlem  40.80518 -73.95359             False
# 517                   NaN  40.71580 -73.95803             False
# 547                   NaN  40.73089 -73.98195              True
# 553                   NaN  40.71300 -73.99752              True
# 575                   NaN  40.79816 -73.96190              True
# 589                   NaN  40.68012 -73.97847             False
# 613                   NaN  40.72709 -73.98274              True
# 624                   NaN  40.75348 -73.97065             False
# 633                   NaN  40.71693 -73.98948             False
# 643                   NaN  40.68016 -73.94878             False
# 670                   NaN  40.73641 -73.95330             False
# 678                   NaN  40.73693 -73.95316             False
# 681                   NaN  40.73783 -73.95259              True
# 726                   NaN  40.76217 -73.98411              True
# 731                   NaN  40.78304 -73.97447             False
# 760                   NaN  40.72723 -73.95728              True
# 770                   NaN  40.65992 -73.99042             False
# 779         Crown Heights       NaN       NaN             False
# 785            Greenpoint       NaN       NaN             False
# 799          East Village       NaN       NaN             False
# 814          West Village       NaN       NaN              True
# 843              Elmhurst       NaN       NaN              True
# 885            Greenpoint       NaN       NaN              True
# 926     Flatiron District       NaN       NaN             False
# 986       Upper West Side       NaN       NaN              True
# 40383            Bushwick  40.69085 -73.90937             False
# 40396     Upper West Side  40.79471 -73.96918             False
#
#       cancellation_policy        room_type  construction_year   price  \
# 74               moderate     Private room             2011.0   571.0
# 75                 strict     Private room             2014.0   398.0
# 76                 strict  Entire home/apt             2018.0   618.0
# 77                 strict     Private room             2007.0   116.0
# 78               flexible     Private room             2012.0    54.0
# 90               moderate     Private room             2015.0   266.0
# 91               moderate     Private room             2012.0   728.0
# 92               flexible  Entire home/apt             2021.0   583.0
# 148                strict  Entire home/apt             2003.0   625.0
# 161              moderate     Private room             2022.0  1020.0
# 168                strict     Private room             2004.0   925.0
# 196              flexible     Private room             2021.0   267.0
# 206                strict     Private room             2013.0   936.0
# 241              flexible  Entire home/apt             2011.0   252.0
# 249              moderate  Entire home/apt             2022.0  1028.0
# 262              flexible  Entire home/apt             2016.0   909.0
# 287              moderate  Entire home/apt             2007.0   387.0
# 295              flexible     Private room             2019.0   960.0
# 307              flexible  Entire home/apt             2014.0   651.0
# 319                strict     Private room             2017.0  1080.0
# 361              moderate     Private room             2015.0   671.0
# 384              moderate     Private room             2013.0  1083.0
# 415                strict  Entire home/apt             2022.0   852.0
# 448              moderate     Private room             2013.0   999.0
# 465                strict  Entire home/apt             2010.0   515.0
# 488                strict  Entire home/apt             2007.0  1133.0
# 492                strict     Private room             2016.0   945.0
# 517              moderate  Entire home/apt             2005.0   625.0
# 547                strict  Entire home/apt             2013.0   749.0
# 553              flexible     Private room             2019.0   613.0
# 575                strict  Entire home/apt             2014.0   892.0
# 589                strict     Private room             2003.0   793.0
# 613              moderate     Private room             2004.0   486.0
# 624              moderate  Entire home/apt             2019.0   417.0
# 633              flexible  Entire home/apt             2017.0  1148.0
# 643              moderate  Entire home/apt             2015.0   938.0
# 670                strict  Entire home/apt             2006.0   104.0
# 678              moderate  Entire home/apt             2018.0   914.0
# 681              flexible     Private room             2009.0   528.0
# 726              moderate  Entire home/apt             2003.0   831.0
# 731              flexible  Entire home/apt             2005.0   624.0
# 760                strict     Private room             2020.0   745.0
# 770                strict  Entire home/apt             2007.0  1111.0
# 779                strict     Private room             2003.0   539.0
# 785                strict  Entire home/apt             2021.0  1058.0
# 799              flexible     Private room             2010.0   506.0
# 814                strict  Entire home/apt             2003.0   381.0
# 843                strict     Private room             2005.0   224.0
# 885              flexible     Private room             2019.0   524.0
# 926                strict     Private room             2020.0   623.0
# 986              flexible     Private room             2014.0   413.0
# 40383            flexible     Private room             2011.0   312.0
# 40396            moderate     Private room             2012.0   175.0
#
#        service_fee  minimum_nights  number_of_reviews  \
# 74           114.0             2.0               49.0
# 75            80.0             2.0              105.0
# 76           124.0             5.0               21.0
# 77            23.0             1.0              142.0
# 78            11.0            30.0               25.0
# 90            53.0             3.0              174.0
# 91           146.0             4.0               24.0
# 92           117.0             4.0              166.0
# 148          119.0             3.0               30.0
# 161          204.0             4.0              202.0
# 168          185.0           149.0              294.0
# 196           53.0             1.0              375.0
# 206          187.0             2.0              226.0
# 241           50.0             3.0              135.0
# 249          206.0             3.0              111.0
# 262          182.0             2.0               38.0
# 287           77.0             1.0                9.0
# 295          192.0            30.0               64.0
# 307          130.0            25.0               43.0
# 319          216.0             2.0              220.0
# 361          134.0             1.0               43.0
# 384          217.0            14.0               35.0
# 415          170.0             3.0              150.0
# 448          200.0             1.0               27.0
# 465          103.0             2.0              280.0
# 488          227.0             2.0               15.0
# 492          189.0             5.0               43.0
# 517          130.0             6.0                1.0
# 547          150.0            30.0               25.0
# 553          123.0             1.0              172.0
# 575          178.0             2.0               45.0
# 589          159.0             2.0               23.0
# 613           97.0             1.0              109.0
# 624           83.0            30.0              136.0
# 633          230.0             5.0                8.0
# 643          188.0             3.0                5.0
# 670           21.0             3.0               24.0
# 678          183.0             3.0               30.0
# 681          106.0             3.0                3.0
# 726          166.0             5.0                8.0
# 731          125.0            30.0               16.0
# 760          149.0             4.0                6.0
# 770          222.0           180.0                1.0
# 779          108.0             1.0                1.0
# 785          212.0             5.0               14.0
# 799          101.0             6.0                1.0
# 814           76.0            20.0              157.0
# 843           45.0             1.0               63.0
# 885          105.0            14.0               22.0
# 926          125.0            21.0                0.0
# 986           83.0             1.0               25.0
# 40383         62.0             1.0                0.0
# 40396         35.0             4.0                2.0
#
#                         last_review  reviews_per_month review_rate_number  \
# 74    2019-06-18 00:00:00.000000000               1.60                2.0
# 75    2019-06-26 00:00:00.000000000               0.92                1.0
# 76    2019-01-02 00:00:00.000000000               0.20                4.0
# 77    2019-07-06 00:00:00.000000000               1.50                4.0
# 78    2019-06-10 18:47:53.419776768               0.22                2.0
# 90    2019-06-22 00:00:00.000000000               1.54                5.0
# 91    2019-06-10 18:47:53.419776768               0.28                5.0
# 92    2019-06-27 00:00:00.000000000               3.40                2.0
# 148   2019-06-17 00:00:00.000000000               0.28                5.0
# 161   2019-05-28 00:00:00.000000000               1.86                5.0
# 168   2019-06-24 00:00:00.000000000               1.00                3.0
# 196   2019-06-18 00:00:00.000000000               3.52                3.0
# 206   2019-06-06 00:00:00.000000000               2.12                4.0
# 241   2019-06-20 00:00:00.000000000               1.30                1.0
# 249   2019-06-10 18:47:53.419776768               2.13                5.0
# 262   2019-06-27 00:00:00.000000000               0.50                4.0
# 287   2019-02-16 00:00:00.000000000               0.11                4.0
# 295   2018-07-06 00:00:00.000000000               0.68                1.0
# 307   2019-06-17 00:00:00.000000000               0.42                5.0
# 319   2019-06-22 00:00:00.000000000               2.17                3.0
# 361   2019-07-08 00:00:00.000000000               0.45                5.0
# 384   2019-06-01 00:00:00.000000000               0.35                5.0
# 415   2019-07-05 00:00:00.000000000               1.55                3.0
# 448   2017-10-08 00:00:00.000000000               0.28                1.0
# 465   2019-07-05 00:00:00.000000000               2.92                1.0
# 488   2016-02-15 00:00:00.000000000               0.16                5.0
# 492   2018-01-03 00:00:00.000000000               0.47                3.0
# 517   2016-01-01 00:00:00.000000000               0.02                5.0
# 547   2018-04-30 00:00:00.000000000               0.26                4.0
# 553   2019-07-02 00:00:00.000000000               1.84                5.0
# 575   2019-04-22 00:00:00.000000000               0.47                4.0
# 589   2018-09-15 00:00:00.000000000               0.24                1.0
# 613   2015-10-02 00:00:00.000000000               1.15                2.0
# 624   2019-06-19 00:00:00.000000000               1.45                4.0
# 633   2018-05-18 00:00:00.000000000               0.11                3.0
# 643   2017-07-09 00:00:00.000000000               0.05                2.0
# 670   2018-11-06 00:00:00.000000000               0.32                4.0
# 678   2019-07-03 00:00:00.000000000               0.32                5.0
# 681   2015-11-03 00:00:00.000000000               0.03                2.0
# 726   2015-01-08 00:00:00.000000000               0.09                3.0
# 731   2019-03-31 00:00:00.000000000               0.17                4.0
# 760   2019-04-21 00:00:00.000000000               0.07                3.0
# 770   2016-09-01 00:00:00.000000000               0.03                4.0
# 779   2017-03-18 00:00:00.000000000               0.04                2.0
# 785   2019-06-19 00:00:00.000000000               0.16                5.0
# 799   2013-05-06 00:00:00.000000000               0.01                1.0
# 814   2016-08-11 00:00:00.000000000               1.71                4.0
# 843   2019-05-18 00:00:00.000000000               0.89                3.0
# 885   2019-05-02 00:00:00.000000000               0.25                1.0
# 926   2019-06-10 18:47:53.419776768               1.00                2.0
# 986   2013-06-22 00:00:00.000000000               0.28                2.0
# 40383 2019-06-10 18:47:53.419776768               1.00                4.0
# 40396 2019-02-22 00:00:00.000000000               0.37                2.0
#
#        calculated_host_listings_count  availability_365  \
# 74                                2.0               0.0
# 75                                1.0               0.0
# 76                                1.0               0.0
# 77                                1.0               0.0
# 78                                1.0               0.0
# 90                                4.0               0.0
# 91                                1.0               0.0
# 92                                1.0               0.0
# 148                               1.0             344.0
# 161                               2.0             377.0
# 168                               3.0             311.0
# 196                               1.0               0.0
# 206                               3.0             263.0
# 241                               3.0             109.0
# 249                               1.0             150.0
# 262                              13.0               0.0
# 287                               1.0             323.0
# 295                               1.0              52.0
# 307                               1.0              87.0
# 319                               2.0             361.0
# 361                               1.0             150.0
# 384                               1.0              61.0
# 415                               1.0               0.0
# 448                               4.0             181.0
# 465                               3.0              94.0
# 488                               1.0             326.0
# 492                               2.0             147.0
# 517                               1.0             266.0
# 547                               1.0              67.0
# 553                               2.0              63.0
# 575                               3.0               4.0
# 589                               6.0               0.0
# 613                               1.0             116.0
# 624                               1.0             272.0
# 633                               1.0              42.0
# 643                               1.0             408.0
# 670                              28.0             419.0
# 678                              28.0             296.0
# 681                              28.0             216.0
# 726                               1.0             322.0
# 731                               5.0              24.0
# 760                               1.0              20.0
# 770                               1.0             163.0
# 779                               1.0              41.0
# 785                               1.0             226.0
# 799                               1.0             240.0
# 814                               1.0              61.0
# 843                               2.0              70.0
# 885                               1.0             266.0
# 926                               1.0             104.0
# 986                               1.0             259.0
# 40383                             1.0             269.0
# 40396                             1.0               0.0
#
#                                              house_rules
# 74     The usual courtesies apply: - No smoking - No ...
# 75     Shoes off please Cat can go in or out as he de...
# 76                                      no smoking quiet
# 77     I'm a semi kosher vegetarian which means that ...
# 78     No Street Shoes allowed in House. No cooking K...
# 90     Dryer and Washing Machine are in Basement (1.0...
# 91     To enjoy, relax, feel safe and cozy. Also, kee...
# 92     We ask that guests be respectful as there are ...
# 148                        No Smoking No Pets No Parties
# 161    No smoking in the apartment, even with the win...
# 168                                                  NaN
# 196    ANDREA'S HOUSE RULES:  ** All overnight guests...
# 206    This is a non smoking house.  Quiet hours are ...
# 241    I'm a semi kosher vegetarian which means that ...
# 249    Please review the terms of this rental agreeme...
# 262    Please do not let any of the animals outside! ...
# 287    Maximum of 2 guests staying in the studio.  No...
# 295                                               #NAME?
# 307    - No shoes in apartment - No parties - Enjoy y...
# 319                                                  NaN
# 361               - no shoes inside - quiet after 8:30pm
# 384    I feel very responsible and accountable for yo...
# 415                                                  NaN
# 448                                                  NaN
# 465                                                  NaN
# 488    Please remember that this is a residential bui...
# 492                                                  NaN
# 517    1. No parties. 2. Respect the neighbors.  Nois...
# 547                                                  NaN
# 553    Please be gentle with the furniture and applia...
# 575                                                  NaN
# 589    Please remember that this is a residential bui...
# 613                                               #NAME?
# 624    Please remember that this is a residential bui...
# 633                                                  NaN
# 643    Smoking is allowed on the patio only. No pets ...
# 670                                                  NaN
# 678    House Rules Welcome to Boston-Furnished-Rental...
# 681    PLEASE  NOTE: • 6.25% MA State Sales Tax is al...
# 726    Please Note: This unit was just renovated in A...
# 731    No smoking, no pets, no parties please. Respec...
# 760                                                  NaN
# 770                                                  NaN
# 779    - Weekly and monthly prices are much lower - P...
# 785    We live and let live - hoping that you'd be re...
# 799    Expect respect for the family and the space--t...
# 814    Please keep it clean, thats all we really ask ...
# 843                                                  NaN
# 885    Pets are cool (just clean up after them!), smo...
# 926                                                  NaN
# 986                                   No Smoking No Pets
# 40383                                                NaN
# 40396                     No pets. No smoking. Please :)

# %%
print(f"Total rows before dropping: {len(df)}")
print(f"Rows to be removed: {len(nan_rows)}")
# Out:
# Total rows before dropping: 102058
# Rows to be removed: 53

# %%
#Remove rows use dropna() on selected columns
df_cleaned = df.dropna(subset=['neighbourhood_group', 'neighbourhood', 'lat', 'long'])

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102005 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102005 non-null  int64
#  1   host_identity_verified          102005 non-null  category
#  2   neighbourhood_group             102005 non-null  object
#  3   neighbourhood                   102005 non-null  object
#  4   lat                             102005 non-null  float64
#  5   long                            102005 non-null  float64
#  6   instant_bookable                102005 non-null  bool
#  7   cancellation_policy             102005 non-null  category
#  8   room_type                       102005 non-null  category
#  9   construction_year               102005 non-null  float64
#  10  price                           102005 non-null  float64
#  11  service_fee                     102005 non-null  float64
#  12  minimum_nights                  102005 non-null  float64
#  13  number_of_reviews               102005 non-null  float64
#  14  last_review                     102005 non-null  datetime64[ns]
#  15  reviews_per_month               102005 non-null  float64
#  16  review_rate_number              102005 non-null  category
#  17  calculated_host_listings_count  102005 non-null  float64
#  18  availability_365                102005 non-null  float64
#  19  house_rules                     50178 non-null   object
# dtypes: bool(1), category(4), datetime64[ns](1), float64(10), int64(1), object(3)
# memory usage: 12.9+ MB

# %%
df_cleaned.isnull().sum()
# Out:
# id                                    0
# host_identity_verified                0
# neighbourhood_group                   0
# neighbourhood                         0
# lat                                   0
# long                                  0
# instant_bookable                      0
# cancellation_policy                   0
# room_type                             0
# construction_year                     0
# price                                 0
# service_fee                           0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                     0
# review_rate_number                    0
# calculated_host_listings_count        0
# availability_365                      0
# house_rules                       51827
# dtype: int64

# %% [markdown]
# <h3>Export Clean data for data analysis</h3>

# %%
df_cleaned.to_csv('/Users/kammiehui/Jupyter Notebook/DataSet/Airbnb_Open_Data_Clean.csv', index = False)
